# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from patsy import dmatrix
from time import time
from datetime import datetime as dt
plt.rc('font', family='SimHei', size=14)  # 中文显示必须
# %matplotlib inline
no_uf = pd.read_csv(r'csv/news_n.csv', encoding='utf-8')
yes_uf = pd.read_csv(r'csv/news_y.csv', encoding='utf-8')

df = pd.concat([yes_uf, no_uf], ignore_index=True)  # ignore_index 重新生成index
df_text = df.applymap(lambda x: x.strip() if isinstance(x, str) else np.nan)
# df_text['text']
# df['wanted']

# %%
# import jieba
# import jieba.posseg as pseg
# import re
# corpus = []
# # pattern = r'^[0-9]*$'
# pattern = '((?=[\x21-\x7e]+)[^A-Za-z])'
# for t in df_text['text']:
#     w = ''
#     words = pseg.cut(str(t))
#     for key in words:
#         # 对key.word中的数字和特殊字符进行过滤.
#         isNum = re.search(pattern, str(key.word))
#         if not isNum:
#             w += (key.word + ' ')
#     corpus.append(w)
# print(len(corpus))


import jieba
import jieba.posseg as pseg
import re
corpus = []
# pattern = r'^[0-9]*$'
pattern = '((?=[\x21-\x7e]+)[^A-Za-z])'

for index,t in enumerate(df_text['text']):
    w = ''
    words = pseg.cut(str(t))
    for key in words:
        # 对key.word中的数字和特殊字符进行过滤.
        isNum = re.search(pattern, str(key.word))
        if not isNum:
            w += (key.word + ' ')
    df_text['text'][index] = w
print(len(df_text))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 1.672 seconds.
# Prefix dict has been built succesfully.
# 750

# %%
# stop_words = pd.read_csv(r'C:\Users\Administrator\Desktop\stop_word.csv',encoding = 'utf-8')
import os
import sys
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# 将文档转换为tf-idf向量
vect = TfidfVectorizer()
tv = vect.fit_transform(df_text['text'])
tv
# Out:
# <750x34577 sparse matrix of type '<class 'numpy.float64'>'
# 	with 213403 stored elements in Compressed Sparse Row format>

# %%
# 创建模型，将tf-idf矩阵传递给SVM模型
clf = LinearSVC()
model = clf.fit(tv, df_text['wanted'])
model
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
#　将新下载的文章转为DataFrame
test_uf = pd.read_csv(r'csv/test03.csv', encoding='utf-8')
zf = test_uf['text'].apply(lambda x: str(x).lstrip()) # 去除空格
zf.reset_index(drop=True, inplace=True)

# 将数据转为向量矩阵
test_matrix = vect.transform(zf) 
test_matrix
# Out:
# <19x34577 sparse matrix of type '<class 'numpy.float64'>'
# 	with 217 stored elements in Compressed Sparse Row format>

# %%
# 将向矩阵传递给模型，以获取预测结果.
results = pd.DataFrame(model.predict(test_matrix), columns = ['wanted'])
results
# Out:
#    wanted
# 0       n
# 1       n
# 2       n
# 3       n
# 4       y
# 5       n
# 6       n
# 7       n
# 8       n
# 9       n
# 10      n
# 11      n
# 12      n
# 13      n
# 14      n
# 15      n
# 16      n
# 17      n
# 18      n

# %%
